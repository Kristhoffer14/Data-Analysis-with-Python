# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from random import randint

# %%
n=80
#sample_size=randint(100,1000) 

x1 = np.random.normal(0, 1, 150)
x2 = np.random.gamma(1,1.5, 150)
x3 = np.random.exponential(2, 150)
x4 = np.random.uniform(-4,4, 150)


def update(curr):
    if curr==3:
        fig.tight_layout() #Ordena tempranamente el espaciado de las subplots
    
    if curr==n:
        a.event_source.stop()
    ax1.hist(x1[:curr],color='blue')
    ax1.set_title('Normal Distribution \nn={}'.format(curr))
    ax1.axis([-5,5,0,30])
    
    ax2.hist(x2[:curr],color='orange')
    ax2.set_title('Gamma Distribution \nn={}'.format(curr))
    ax2.axis([-2,18,0,45])
    
    ax3.hist(x3[:curr],color='yellow')
    ax3.set_title('Exponential Distribution \nn={}'.format(curr))
    ax3.axis([-2,16,0,45])
    
    ax4.hist(x4[:curr],color='green')
    ax4.set_title('Uniform Distribution \nn={}'.format(curr))
    ax4.axis([-5,5,0,20])
    
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2)
a=animation.FuncAnimation(fig,update,interval=10)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
